# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..'))) 

from src import DataCleaner 

import pandas as pd


raw_data = pd.read_csv('../data/data.csv')

# Chain the methods together!
cleaner = DataCleaner(raw_data)
final_df = (cleaner
            .fix_columns()
            .handle_missing_values(strategy='mean')
            .remove_duplicates()
            .get_clean_data())

final_df.head()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 5
#       2 import os
#       3 sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
# ----> 5 from src import DataCleaner
#       7 import pandas as pd
#      10 raw_data = pd.read_csv('../data/data.csv')
#
# ImportError: cannot import name 'DataCleaner' from 'src' (b:\full_stack_data_science\src\__init__.py)
